# %% [markdown]
# Nombre de la entrega : Semana 7_Data Analysis with Python (IBM)
#
# Alumno : Francisco Javier Hernandez Camarillo,
#
# Matricula: 00998083,
#
# Materia: Ciencia y analitica de datos
#
# Profesor: Dra. María de la Paz Rico Fernández.
#
# Fecha: 27/OCT/2022

# %% [markdown]
# # Model Development
#
# trying to predict the price of a car using our dataset.
#
# - Simple and Multiple Linear Regression
# - Model Evaluation using Visualization
# - Polynomial Regression and Pipelines
# - R-squared and MSE for In-Sample Evaluation
# - Prediction and Decision Making
#
# A model or estimator can be thought of as a mathematical equation used to predict a value given one or more other values
#
# for example if we input the car's model highway miles per gallon as independet value , the output of the model could be the prize
#
# usually if our data is relevant our prediction would be accurate
#
# if we input multiple independet features , the prediction would be more accurate
#
#
# for example in the case we have a lot of variables , and we ahve to identical cars but the color, if we dont consider the color in the model therefore the prediction would be the same price for both .
#
# to getting more data, we can try different types of models.
#
# - Simple Linear Regression
# - Multiple Linear Regression
# - Polynomial Regression
#
# models to be studied

# %% [markdown]
# # Linear and Multiple Linear Regression
#
# Linear Regression will refer to one independent variable to make a prediction.
#
# Multiple Linear Regression will refer to multiple independent variables to make a prediction.
#
# SLR is a method to understan how 2 variables are related
#
# predictor (independet) x
#
# target (dependent) y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we we fit (train the model ) we will come up thi these parameters (above)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we use the training points to fit our model
#
# the result of the training plots are the parameters like the slope and the intercept
#
# We usually store the data points in two dataframe
# or numpy arrays.
#
# he value we would like to predict is called
# the target that we store in the array y
#
# about the noise, they are point that doesnt match with the normal behaviour
#
# to create a model and fit it , we need the model from sklearn
# create the linear regression object
# we define the predictr variable and the target
#
# Then use the method fit to fit the model and
# find the parameters b0 and b1.
#
#  The input are the features and the targets.
#
#  We can obtain a prediction using the method predict.
#
# The output is an array, the array has the same number of samples as the input X.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we can get the interceptor and the slope whit the methods above

# %% [markdown]
# Multiple Linear Regression is used to explain the relationship between
# - One continuous target (Y) variable, and - Two or more predictor (X) variables.
#
# If there are only two variables then we can visualize the values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we can predict using all of our variablea as a data
#
# The intercept is an attribute of the object. And the coefficients are also attributes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Model Evaluation using Visualization
#
# we’ll look at model evaluation using visualization.
#
# Regression plots are a good estimate of:
# - The relationship between two variables,
# - The strength of the correlation, and
# - The direction of the relationship (positive or negative).
#
# The horizontal axis is the independent variable.
# The vertical axis is the dependent variable.
#
# theres a simple way to plot , it is to use "regplot" from the seaborn library.
#
# use the "regplot" function.
#
# The parameter x is the name of the column that contains the dependent variable or feature.
#
# The parameter y contains the name of the column that contains the name of the dependent variable
#
# parameter data is the name of the data frame
#
# The residual plot represents the error between the actual values.
#
# Examining the predicted value and actual value we see a difference.
#
# We obtain that value by subtracting the predicted value and the actual target value.
#
# We expect to see the results to have zero mean.
#
#
# **The residuals are not randomly separated; this suggests the linear assumption is incorrect.**
#
# we see that variance of the residuals increases with x, therefore our model is incorrect.
#
# We can use seaborn to create a Residual Plot.
#
#
# A **distribution plot** counts the predicted value versus the actual value.
#
# These plots are extremely useful for visualizing models with more than one independent variable
#
#
# A histogram is for discrete values.
#
# Therefore pandas will convert them to a distribution.
#
# distribution plots are very usefull to compare the training value with the validation value

# %% [markdown]
# # Polynomial Regression and Pipelines
#
# what to do if linear regression is no the appropiate
#
# pipelines = Pipelines are a way to simplify your code.
#
# Polynomial regression is a special case of the general linear regression.
#
# This method is beneficial for describing curvilinear relationships. it is what we get when we have square or higher order terms in our predictor value transforming the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# how the graph changes when we have great polinomial regression
#
# In all cases, the relationship between the variable and the parameter is always linear.
#
# polyfit() = for polynomial regression model
#
# We can also have multi-dimensional polynomial linear regression.
#
# Numpys “polyfit” function cannot perform this type of regression.
#
# We use the "preprocessing" library in sci-kit-learn, to create a polynomial feature object.
#
# As the dimension of the data gets larger we may want to normalize multiple features
#
# we can Standardize each feature simultaneously.
#
# when we transform we can put different columns of the data inside the data()
#
# ## pipelines
#
# we can reduce the process of , normalizaiton > polunomial regression > linear regression using a pipeline
#
# ***Pipelines sequentially perform a series of transformation.***
#
# we need to  import the library Pipeline.
#
# we can predict using the pipe line
#
# pipe.predict(data)

# %% [markdown]
# # Measures for In-Sample Evaluation
#
# we want to numerically evaluate our models.
#
# These measures are a way to numerically determine how good the model fits on our data.
#
# Two important measures that we often use to determine the fit of a model are: Mean Square
# Error (MSE), and R-squared.
#
# In this case, the actual value is 150; the predicted value is 50. Subtracting these points
# we get 100.
#
# To find the MSE in Python, we can import the “mean_Squared_error()” from “scikit-learn.metrics”.
#
# R-squared is also called the coefficient of determination. I
#
# If we Plug in this value from the previous slide for R^2, we get a value near one, this
# means the line is a good fit for the data.
#
# We find the R-squared value in Python by using the score() method, in the linear regression object.

# %% [markdown]
# # Prediction and Decision Making
#
# The first thing we should do is make sure our model results make sense.
#
# You should always use Visualization, Numerical measures for evaluation, and Comparing between
#
# Sometimes your model will produce values that don't make sense,
#
# This could be because the values in that range are not realistic,
#
# The mean square error is perhaps the most intuitive Numerical measure for determining if a model is good or not
#
# An acceptable value for R^2 depends on what field you’re studying.
# Some authors suggest a value should be equal to or greater than 0.10.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
